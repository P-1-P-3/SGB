# %% [markdown]
# # **Gestion de Biblioteca**

# %% [markdown]
# # Ejecución del programa - Menu
#
#
# > Nota: Antes de ejecutar esta clase debera ejecutar primero las clases: Biblioteca, Usuario, Libro y Bibliotecario.

# %%
class LibraryMenu:
    def __init__(self):
        self.library = Library()

    def showMenu(self):
        print("\n\n---Menú de Biblioteca---")
        print("1. Agregar Usuario")
        print("2. Agregar Libro")
        print("3. Mostrar Libros")
        print("4. Buscar Libro")
        print("5. Recuperar ultimo libro consultado")
        print("6. Prestar Libro")
        print("7. Mostrar libros prestados")
        print("8. Devolver Libro")
        print("------------------------")
        print("9.  Buscar Usuario")
        print("10. Mostrar Usuarios")
        print("11. Buscar Libro")
        print("12. Buscar Libros por editorial y autor")
        print("13. Mostrar Libros")
        print("------------------------")
        print("0. Salir")
        print("------------------------")
        option = input("Selecciona una opción: ")
        self.optionSelected(option)

    def optionSelected(self, option):
        case = {
            "0":  self.library.exit,
            "1":  self.library.addUser,
            "2":  self.library.addBook,
            "3":  self.library.showBooks,
            "4":  self.library.searchBook,
            "5":  self.library.recoverHistoryBook,
            "6":  self.library.lendBook,
            "7":  self.library.showLentBooks,
            "8":  self.library.returnBook,
            "9":  self.library.searchUserTree,
            "10": self.library.showUsersTree,
            "11": self.library.searchBookTree,
            "12": self.library.searchBookNTree,
            "13": self.library.showBooksTree,
        }

        case.get(option, self.showMenu)()
        if option != "0":
          self.showMenu()

    def loadData(self):
        self.library.loadData()

#--- EJecución del programa
libraryMenu = LibraryMenu()
libraryMenu.loadData()
libraryMenu.showMenu()
# Out:
# ---Menú de Biblioteca---
# 1. Agregar Usuario
# 2. Agregar Libro
# 3. Mostrar Libros
# 4. Buscar Libro
# 5. Recuperar ultimo libro consultado
# 6. Prestar Libro
# 7. Mostrar libros prestados
# 8. Devolver Libro
# ------------------------
# 9.  Buscar Usuario
# 10. Mostrar Usuarios
# 11. Buscar Libro
# 12. Buscar Libros por editorial y autor
# 13. Mostrar Libros
# ------------------------
# 0. Salir
# ------------------------
# Selecciona una opción: 1
# Ingresa el id del usuario: 1234567
# Ingresa el nombre del usuario: Andres
# Ingresa el correo del usuario: prueba@gmail.com
# El usuario Andres ha sido agregado
#
#
# ---Menú de Biblioteca---
# 1. Agregar Usuario
# 2. Agregar Libro
# 3. Mostrar Libros
# 4. Buscar Libro
# 5. Recuperar ultimo libro consultado
# 6. Prestar Libro
# 7. Mostrar libros prestados
# 8. Devolver Libro
# ------------------------
# 9.  Buscar Usuario
# 10. Mostrar Usuarios
# 11. Buscar Libro
# 12. Buscar Libros por editorial y autor
# 13. Mostrar Libros
# ------------------------
# 0. Salir
# ------------------------
# Selecciona una opción: 2
# Ingresa el ISBN del libro: 1100000001
# Ingresa el título del libro: Prueba
# Ingresa el autor del libro: Andres s
# Ingresa la editorial del libro: Editorial Anagrama
# Ingresa el año de publicación del libro: 2001
# El libro Prueba ha sido agregado
#
#
# ---Menú de Biblioteca---
# 1. Agregar Usuario
# 2. Agregar Libro
# 3. Mostrar Libros
# 4. Buscar Libro
# 5. Recuperar ultimo libro consultado
# 6. Prestar Libro
# 7. Mostrar libros prestados
# 8. Devolver Libro
# ------------------------
# 9.  Buscar Usuario
# 10. Mostrar Usuarios
# 11. Buscar Libro
# 12. Buscar Libros por editorial y autor
# 13. Mostrar Libros
# ------------------------
# 0. Salir
# ------------------------
# Selecciona una opción: 11
# Ingrese el ISBN del libro: 1100000001
# +------------+--------+----------+--------------------+------+
# |    isbn    | Titulo |  Autor   |     Editorial      | Año  |
# +------------+--------+----------+--------------------+------+
# | 1100000001 | Prueba | Andres s | Editorial Anagrama | 2001 |
# +------------+--------+----------+--------------------+------+
#
#
# ---Menú de Biblioteca---
# 1. Agregar Usuario
# 2. Agregar Libro
# 3. Mostrar Libros
# 4. Buscar Libro
# 5. Recuperar ultimo libro consultado
# 6. Prestar Libro
# 7. Mostrar libros prestados
# 8. Devolver Libro
# ------------------------
# 9.  Buscar Usuario
# 10. Mostrar Usuarios
# 11. Buscar Libro
# 12. Buscar Libros por editorial y autor
# 13. Mostrar Libros
# ------------------------
# 0. Salir
# ------------------------
# Selecciona una opción: 12
# Ingrese el nombre de la editorial: Editorial Anagrama
# Ingrese el nombre del autor: Andres
# Autor no encontrado
#
#
# ---Menú de Biblioteca---
# 1. Agregar Usuario
# 2. Agregar Libro
# 3. Mostrar Libros
# 4. Buscar Libro
# 5. Recuperar ultimo libro consultado
# 6. Prestar Libro
# 7. Mostrar libros prestados
# 8. Devolver Libro
# ------------------------
# 9.  Buscar Usuario
# 10. Mostrar Usuarios
# 11. Buscar Libro
# 12. Buscar Libros por editorial y autor
# 13. Mostrar Libros
# ------------------------
# 0. Salir
# ------------------------
# Selecciona una opción: 12
# Ingrese el nombre de la editorial: Editorial Anagrama
# Ingrese el nombre del autor: Andres s
# +------------+--------+----------+--------------------+------+
# |    isbn    | Titulo |  Autor   |     Editorial      | Año  |
# +------------+--------+----------+--------------------+------+
# | 1100000001 | Prueba | Andres s | Editorial Anagrama | 2001 |
# +------------+--------+----------+--------------------+------+
#
#
# ---Menú de Biblioteca---
# 1. Agregar Usuario
# 2. Agregar Libro
# 3. Mostrar Libros
# 4. Buscar Libro
# 5. Recuperar ultimo libro consultado
# 6. Prestar Libro
# 7. Mostrar libros prestados
# 8. Devolver Libro
# ------------------------
# 9.  Buscar Usuario
# 10. Mostrar Usuarios
# 11. Buscar Libro
# 12. Buscar Libros por editorial y autor
# 13. Mostrar Libros
# ------------------------
# 0. Salir
# ------------------------
# Selecciona una opción: 12
# Ingrese el nombre de la editorial: Editorial Sudamericana
# Ingrese el nombre del autor: Miguel de Cervantes
# +------------+-----------------+---------------------+------------------------+------+
# |    isbn    |      Titulo     |        Autor        |       Editorial        | Año  |
# +------------+-----------------+---------------------+------------------------+------+
# | 1000000003 | Pedro Páramo 10 | Miguel de Cervantes | Editorial Sudamericana | 1976 |
# +------------+-----------------+---------------------+------------------------+------+
#
#
# ---Menú de Biblioteca---
# 1. Agregar Usuario
# 2. Agregar Libro
# 3. Mostrar Libros
# 4. Buscar Libro
# 5. Recuperar ultimo libro consultado
# 6. Prestar Libro
# 7. Mostrar libros prestados
# 8. Devolver Libro
# ------------------------
# 9.  Buscar Usuario
# 10. Mostrar Usuarios
# 11. Buscar Libro
# 12. Buscar Libros por editorial y autor
# 13. Mostrar Libros
# ------------------------
# 0. Salir
# ------------------------
# Selecciona una opción: 13
# +------------+-------------------------------------+------------------------+----------------------------+------+
# |    isbn    |                Titulo               |         Autor          |         Editorial          | Año  |
# +------------+-------------------------------------+------------------------+----------------------------+------+
# | 1000000001 |            Pedro Páramo 5           |       Juan Rulfo       |     Editorial Anagrama     | 1919 |
# | 1000000002 |      La casa de los espíritus 4     |     Carlos Fuentes     |      Editorial Losada      | 1916 |
# | 1000000003 |           Pedro Páramo 10           |  Miguel de Cervantes   |   Editorial Sudamericana   | 1976 |
# | 1000000004 |  Crónica de una muerte anunciada 4  |     Julio Cortázar     |    Francisco de Robles     | 1938 |
# | 1000000005 |             Ficciones 5             |       Juan Rulfo       |       Editorial Sur        | 2019 |
# | 1000000006 |              Rayuela 3              |       Juan Rulfo       |    Francisco de Robles     | 1904 |
# | 1000000007 |      Don Quijote de la Mancha 2     |  Miguel de Cervantes   | Fondo de Cultura Económica | 1912 |
# | 1000000008 |      Como agua para chocolate 6     |   Carlos Ruiz Zafón    |        Oveja Negra         | 1959 |
# | 1000000009 | El amor en los tiempos del cólera 2 |  Miguel de Cervantes   |            Sur             | 1940 |
# | 1000000010 |      Los detectives salvajes 6      |   Jorge Luis Borges    |            Sur             | 1965 |
# | 1000000011 |      Los detectives salvajes 8      | Gabriel García Márquez |       Editorial Sur        | 1917 |
# | 1000000012 |             Ficciones 8             |   Jorge Luis Borges    |            Sur             | 1955 |
# | 1000000013 |           Pedro Páramo 10           |     Roberto Bolaño     |   Editorial Sudamericana   | 2011 |
# | 1000000014 |        La fiesta del chivo 4        |   Carlos Ruiz Zafón    |          Planeta           | 1960 |
# | 1000000015 |             Ficciones 8             |   Jorge Luis Borges    |     Editorial Anagrama     | 1925 |
# | 1000000016 |             Ficciones 7             | Gabriel García Márquez |    Francisco de Robles     | 1965 |
# | 1000000017 | El amor en los tiempos del cólera 2 |   Carlos Ruiz Zafón    |   Editorial Sudamericana   | 1935 |
# | 1000000018 |            Santa Evita 10           |       Juan Rulfo       | Fondo de Cultura Económica | 1994 |
# | 1000000019 |              El túnel 1             |  Miguel de Cervantes   |      Editorial Losada      | 1992 |
# | 1000000020 |              El Aleph 1             |  Miguel de Cervantes   |      Editorial Losada      | 1932 |
# | 1000000021 |     La región más transparente 4    |     Ernesto Sabato     |      Editorial Losada      | 1925 |
# | 1000000022 |           Pedro Páramo 10           |  Miguel de Cervantes   |     Editorial Anagrama     | 1901 |
# | 1000000023 |      La casa de los espíritus 6     |     Julio Cortázar     |      Editorial Losada      | 1952 |
# | 1000000024 |      Como agua para chocolate 9     |       Juan Rulfo       |       Editorial Sur        | 1977 |
# | 1000000025 |  Crónica de una muerte anunciada 3  | Gabriel García Márquez |   Editorial Sudamericana   | 1922 |
# | 1000000026 |                Aura 3               |     Ernesto Sabato     | Fondo de Cultura Económica | 2000 |
# | 1000000027 | El amor en los tiempos del cólera 8 |  Miguel de Cervantes   |       Editorial Sur        | 1972 |
# | 1000000028 | El amor en los tiempos del cólera 7 |     Julio Cortázar     |      Editorial Losada      | 1966 |
# | 1000000029 |      Don Quijote de la Mancha 2     |     Julio Cortázar     | Fondo de Cultura Económica | 1904 |
# | 1000000030 |            Pedro Páramo 9           |  Miguel de Cervantes   | Fondo de Cultura Económica | 1933 |
# | 1000000031 |       Sobre héroes y tumbas 2       |     Carlos Fuentes     |       Editorial Sur        | 2011 |
# | 1000000032 |  Crónica de una muerte anunciada 5  |   Jorge Luis Borges    |    Francisco de Robles     | 1903 |
# | 1000000033 |        La fiesta del chivo 1        |     Roberto Bolaño     | Fondo de Cultura Económica | 1963 |
# | 1000000034 |        Cien años de soledad 3       |  Miguel de Cervantes   |        Oveja Negra         | 1954 |
# | 1000000035 | El amor en los tiempos del cólera 8 |     Ernesto Sabato     |   Editorial Sudamericana   | 1984 |
# | 1000000036 |        La fiesta del chivo 2        |     Ernesto Sabato     |    Francisco de Robles     | 1904 |
# | 1000000037 |            Santa Evita 1            |     Roberto Bolaño     |     Editorial Anagrama     | 1925 |
# | 1000000038 |              El túnel 3             |   Carlos Ruiz Zafón    |   Editorial Sudamericana   | 1963 |
# | 1000000039 |  Crónica de una muerte anunciada 7  | Gabriel García Márquez |     Editorial Anagrama     | 2019 |
# | 1000000040 |      Los detectives salvajes 5      |     Julio Cortázar     | Fondo de Cultura Económica | 1903 |
# | 1000000041 |        La fiesta del chivo 1        |     Julio Cortázar     |    Francisco de Robles     | 1935 |
# | 1000000042 |     La región más transparente 6    |     Ernesto Sabato     |   Editorial Sudamericana   | 1922 |
# | 1000000043 |        La fiesta del chivo 5        |       Juan Rulfo       |      Editorial Losada      | 1949 |
# | 1000000044 |       La ciudad y los perros 8      |     Roberto Bolaño     |       Editorial Sur        | 1901 |
# | 1000000045 |  Crónica de una muerte anunciada 5  |  Miguel de Cervantes   |        Oveja Negra         | 1905 |
# | 1000000046 |      Don Quijote de la Mancha 5     |     Julio Cortázar     |      Editorial Losada      | 1974 |
# | 1000000047 |     La región más transparente 5    | Gabriel García Márquez | Fondo de Cultura Económica | 1914 |
# | 1000000048 |        Cien años de soledad 4       |     Ernesto Sabato     |        Oveja Negra         | 1933 |
# | 1000000049 |      Como agua para chocolate 9     |     Roberto Bolaño     |     Editorial Anagrama     | 1975 |
# | 1000000050 |            Pedro Páramo 4           |     Roberto Bolaño     |          Planeta           | 1936 |
# | 1000000051 |        La fiesta del chivo 1        |     Carlos Fuentes     |     Editorial Anagrama     | 1999 |
# | 1000000052 |        Cien años de soledad 4       |  Miguel de Cervantes   |        Oveja Negra         | 2013 |
# | 1000000053 |        La fiesta del chivo 5        |     Ernesto Sabato     |        Oveja Negra         | 1975 |
# | 1000000054 |      Don Quijote de la Mancha 8     |     Carlos Fuentes     |            Sur             | 1906 |
# | 1000000055 |       La ciudad y los perros 2      |       Juan Rulfo       |    Francisco de Robles     | 1903 |
# | 1000000056 |        La fiesta del chivo 4        |  Miguel de Cervantes   |        Oveja Negra         | 1985 |
# | 1000000057 |      Don Quijote de la Mancha 2     |     Roberto Bolaño     |          Planeta           | 1925 |
# | 1000000058 |            Santa Evita 9            |   Carlos Ruiz Zafón    |   Editorial Sudamericana   | 1970 |
# | 1000000059 |        La fiesta del chivo 6        |   Carlos Ruiz Zafón    |   Editorial Sudamericana   | 1905 |
# | 1000000060 |  Crónica de una muerte anunciada 2  |     Roberto Bolaño     |          Planeta           | 1920 |
# | 1000000061 |              Rayuela 6              |     Carlos Fuentes     |     Editorial Anagrama     | 1974 |
# | 1000000062 |                Aura 3               | Gabriel García Márquez |        Oveja Negra         | 1992 |
# | 1000000063 |            Pedro Páramo 1           |       Juan Rulfo       | Fondo de Cultura Económica | 1985 |
# | 1000000064 |      Don Quijote de la Mancha 4     |     Julio Cortázar     |        Oveja Negra         | 1990 |
# | 1000000065 |      Don Quijote de la Mancha 6     |     Carlos Fuentes     |      Editorial Losada      | 1944 |
# | 1000000066 |      Los detectives salvajes 2      |   Jorge Luis Borges    |          Planeta           | 1908 |
# | 1000000067 |      La casa de los espíritus 8     |     Roberto Bolaño     |     Editorial Anagrama     | 1928 |
# | 1000000068 |      Los detectives salvajes 5      |       Juan Rulfo       |   Editorial Sudamericana   | 1901 |
# | 1000000069 |        Noticias del imperio 7       |     Julio Cortázar     |        Oveja Negra         | 1941 |
# | 1000000070 |      Como agua para chocolate 3     |     Ernesto Sabato     |    Francisco de Robles     | 2015 |
# | 1000000071 |            Pedro Páramo 3           |     Ernesto Sabato     | Fondo de Cultura Económica | 1973 |
# | 1000000072 |        Cien años de soledad 7       |   Jorge Luis Borges    |       Editorial Sur        | 1971 |
# | 1000000073 |  Crónica de una muerte anunciada 4  |  Miguel de Cervantes   |       Editorial Sur        | 1992 |
# | 1000000074 |        La fiesta del chivo 1        |       Juan Rulfo       |   Editorial Sudamericana   | 1960 |
# | 1000000075 |  Crónica de una muerte anunciada 8  |     Ernesto Sabato     |       Editorial Sur        | 1902 |
# | 1000000076 |             Ficciones 9             |       Juan Rulfo       |   Editorial Sudamericana   | 1963 |
# | 1000000077 |      La casa de los espíritus 4     |   Carlos Ruiz Zafón    |       Editorial Sur        | 1938 |
# | 1000000078 |       La ciudad y los perros 1      |   Carlos Ruiz Zafón    |     Editorial Anagrama     | 1997 |
# | 1000000079 |  Crónica de una muerte anunciada 3  | Gabriel García Márquez |       Editorial Sur        | 1977 |
# | 1000000080 |      Los detectives salvajes 1      |     Roberto Bolaño     |    Francisco de Robles     | 1913 |
# | 1000000081 |        La sombra del viento 9       |     Carlos Fuentes     |    Francisco de Robles     | 1977 |
# | 1000000082 |       La ciudad y los perros 2      |     Carlos Fuentes     |      Editorial Losada      | 2023 |
# | 1000000083 |        Cien años de soledad 2       |       Juan Rulfo       |            Sur             | 1922 |
# | 1000000084 |       Sobre héroes y tumbas 10      |   Carlos Ruiz Zafón    |     Editorial Anagrama     | 1996 |
# | 1000000085 |            Pedro Páramo 4           |  Miguel de Cervantes   | Fondo de Cultura Económica | 1954 |
# | 1000000086 |        Cien años de soledad 5       | Gabriel García Márquez |     Editorial Anagrama     | 1920 |
# | 1000000087 |            Santa Evita 4            |     Ernesto Sabato     |            Sur             | 1973 |
# | 1000000088 |      Los detectives salvajes 7      | Gabriel García Márquez |            Sur             | 1970 |
# | 1000000089 |              El Aleph 3             |     Carlos Fuentes     |     Editorial Anagrama     | 1904 |
# | 1000000090 |        La fiesta del chivo 9        |     Roberto Bolaño     |            Sur             | 1974 |
# | 1000000091 | El amor en los tiempos del cólera 7 |     Roberto Bolaño     |   Editorial Sudamericana   | 1958 |
# | 1000000092 |      La casa de los espíritus 5     |   Carlos Ruiz Zafón    |      Editorial Losada      | 1939 |
# | 1000000093 |              El túnel 9             |  Miguel de Cervantes   |        Oveja Negra         | 1978 |
# | 1000000094 |              El Aleph 9             |     Roberto Bolaño     |    Francisco de Robles     | 2012 |
# | 1000000095 |       Sobre héroes y tumbas 6       | Gabriel García Márquez |     Editorial Anagrama     | 1931 |
# | 1000000096 |        La sombra del viento 4       |   Jorge Luis Borges    |    Francisco de Robles     | 1909 |
# | 1000000097 |  Crónica de una muerte anunciada 6  |   Carlos Ruiz Zafón    | Fondo de Cultura Económica | 1920 |
# | 1000000098 |      Don Quijote de la Mancha 1     | Gabriel García Márquez | Fondo de Cultura Económica | 1929 |
# | 1000000099 |      Como agua para chocolate 7     |     Ernesto Sabato     |        Oveja Negra         | 1934 |
# | 1000000100 |              Rayuela 8              | Gabriel García Márquez |          Planeta           | 1933 |
# | 1100000001 |                Prueba               |        Andres s        |     Editorial Anagrama     | 2001 |
# +------------+-------------------------------------+------------------------+----------------------------+------+
#
#
# ---Menú de Biblioteca---
# 1. Agregar Usuario
# 2. Agregar Libro
# 3. Mostrar Libros
# 4. Buscar Libro
# 5. Recuperar ultimo libro consultado
# 6. Prestar Libro
# 7. Mostrar libros prestados
# 8. Devolver Libro
# ------------------------
# 9.  Buscar Usuario
# 10. Mostrar Usuarios
# 11. Buscar Libro
# 12. Buscar Libros por editorial y autor
# 13. Mostrar Libros
# ------------------------
# 0. Salir
# ------------------------
# Selecciona una opción: 12
# Ingrese el nombre de la editorial: Sur
# Ingrese el nombre del autor: Jorge Luis Borges
# +------------+---------------------------+-------------------+-----------+------+
# |    isbn    |           Titulo          |       Autor       | Editorial | Año  |
# +------------+---------------------------+-------------------+-----------+------+
# | 1000000010 | Los detectives salvajes 6 | Jorge Luis Borges |    Sur    | 1965 |
# | 1000000012 |        Ficciones 8        | Jorge Luis Borges |    Sur    | 1955 |
# +------------+---------------------------+-------------------+-----------+------+
#
#
# ---Menú de Biblioteca---
# 1. Agregar Usuario
# 2. Agregar Libro
# 3. Mostrar Libros
# 4. Buscar Libro
# 5. Recuperar ultimo libro consultado
# 6. Prestar Libro
# 7. Mostrar libros prestados
# 8. Devolver Libro
# ------------------------
# 9.  Buscar Usuario
# 10. Mostrar Usuarios
# 11. Buscar Libro
# 12. Buscar Libros por editorial y autor
# 13. Mostrar Libros
# ------------------------
# 0. Salir
# ------------------------
# Selecciona una opción: 2
# Ingresa el ISBN del libro: 1000000101
# Ingresa el título del libro: Prueba 2
# Ingresa el autor del libro: Andres s
# Ingresa la editorial del libro: Editorial Anagrama
# Ingresa el año de publicación del libro: 1994
# El libro Prueba 2 ha sido agregado
#
#
# ---Menú de Biblioteca---
# 1. Agregar Usuario
# 2. Agregar Libro
# 3. Mostrar Libros
# 4. Buscar Libro
# 5. Recuperar ultimo libro consultado
# 6. Prestar Libro
# 7. Mostrar libros prestados
# 8. Devolver Libro
# ------------------------
# 9.  Buscar Usuario
# 10. Mostrar Usuarios
# 11. Buscar Libro
# 12. Buscar Libros por editorial y autor
# 13. Mostrar Libros
# ------------------------
# 0. Salir
# ------------------------
# Selecciona una opción: 13
# +------------+-------------------------------------+------------------------+----------------------------+------+
# |    isbn    |                Titulo               |         Autor          |         Editorial          | Año  |
# +------------+-------------------------------------+------------------------+----------------------------+------+
# | 1000000001 |            Pedro Páramo 5           |       Juan Rulfo       |     Editorial Anagrama     | 1919 |
# | 1000000002 |      La casa de los espíritus 4     |     Carlos Fuentes     |      Editorial Losada      | 1916 |
# | 1000000003 |           Pedro Páramo 10           |  Miguel de Cervantes   |   Editorial Sudamericana   | 1976 |
# | 1000000004 |  Crónica de una muerte anunciada 4  |     Julio Cortázar     |    Francisco de Robles     | 1938 |
# | 1000000005 |             Ficciones 5             |       Juan Rulfo       |       Editorial Sur        | 2019 |
# | 1000000006 |              Rayuela 3              |       Juan Rulfo       |    Francisco de Robles     | 1904 |
# | 1000000007 |      Don Quijote de la Mancha 2     |  Miguel de Cervantes   | Fondo de Cultura Económica | 1912 |
# | 1000000008 |      Como agua para chocolate 6     |   Carlos Ruiz Zafón    |        Oveja Negra         | 1959 |
# | 1000000009 | El amor en los tiempos del cólera 2 |  Miguel de Cervantes   |            Sur             | 1940 |
# | 1000000010 |      Los detectives salvajes 6      |   Jorge Luis Borges    |            Sur             | 1965 |
# | 1000000011 |      Los detectives salvajes 8      | Gabriel García Márquez |       Editorial Sur        | 1917 |
# | 1000000012 |             Ficciones 8             |   Jorge Luis Borges    |            Sur             | 1955 |
# | 1000000013 |           Pedro Páramo 10           |     Roberto Bolaño     |   Editorial Sudamericana   | 2011 |
# | 1000000014 |        La fiesta del chivo 4        |   Carlos Ruiz Zafón    |          Planeta           | 1960 |
# | 1000000015 |             Ficciones 8             |   Jorge Luis Borges    |     Editorial Anagrama     | 1925 |
# | 1000000016 |             Ficciones 7             | Gabriel García Márquez |    Francisco de Robles     | 1965 |
# | 1000000017 | El amor en los tiempos del cólera 2 |   Carlos Ruiz Zafón    |   Editorial Sudamericana   | 1935 |
# | 1000000018 |            Santa Evita 10           |       Juan Rulfo       | Fondo de Cultura Económica | 1994 |
# | 1000000019 |              El túnel 1             |  Miguel de Cervantes   |      Editorial Losada      | 1992 |
# | 1000000020 |              El Aleph 1             |  Miguel de Cervantes   |      Editorial Losada      | 1932 |
# | 1000000021 |     La región más transparente 4    |     Ernesto Sabato     |      Editorial Losada      | 1925 |
# | 1000000022 |           Pedro Páramo 10           |  Miguel de Cervantes   |     Editorial Anagrama     | 1901 |
# | 1000000023 |      La casa de los espíritus 6     |     Julio Cortázar     |      Editorial Losada      | 1952 |
# | 1000000024 |      Como agua para chocolate 9     |       Juan Rulfo       |       Editorial Sur        | 1977 |
# | 1000000025 |  Crónica de una muerte anunciada 3  | Gabriel García Márquez |   Editorial Sudamericana   | 1922 |
# | 1000000026 |                Aura 3               |     Ernesto Sabato     | Fondo de Cultura Económica | 2000 |
# | 1000000027 | El amor en los tiempos del cólera 8 |  Miguel de Cervantes   |       Editorial Sur        | 1972 |
# | 1000000028 | El amor en los tiempos del cólera 7 |     Julio Cortázar     |      Editorial Losada      | 1966 |
# | 1000000029 |      Don Quijote de la Mancha 2     |     Julio Cortázar     | Fondo de Cultura Económica | 1904 |
# | 1000000030 |            Pedro Páramo 9           |  Miguel de Cervantes   | Fondo de Cultura Económica | 1933 |
# | 1000000031 |       Sobre héroes y tumbas 2       |     Carlos Fuentes     |       Editorial Sur        | 2011 |
# | 1000000032 |  Crónica de una muerte anunciada 5  |   Jorge Luis Borges    |    Francisco de Robles     | 1903 |
# | 1000000033 |        La fiesta del chivo 1        |     Roberto Bolaño     | Fondo de Cultura Económica | 1963 |
# | 1000000034 |        Cien años de soledad 3       |  Miguel de Cervantes   |        Oveja Negra         | 1954 |
# | 1000000035 | El amor en los tiempos del cólera 8 |     Ernesto Sabato     |   Editorial Sudamericana   | 1984 |
# | 1000000036 |        La fiesta del chivo 2        |     Ernesto Sabato     |    Francisco de Robles     | 1904 |
# | 1000000037 |            Santa Evita 1            |     Roberto Bolaño     |     Editorial Anagrama     | 1925 |
# | 1000000038 |              El túnel 3             |   Carlos Ruiz Zafón    |   Editorial Sudamericana   | 1963 |
# | 1000000039 |  Crónica de una muerte anunciada 7  | Gabriel García Márquez |     Editorial Anagrama     | 2019 |
# | 1000000040 |      Los detectives salvajes 5      |     Julio Cortázar     | Fondo de Cultura Económica | 1903 |
# | 1000000041 |        La fiesta del chivo 1        |     Julio Cortázar     |    Francisco de Robles     | 1935 |
# | 1000000042 |     La región más transparente 6    |     Ernesto Sabato     |   Editorial Sudamericana   | 1922 |
# | 1000000043 |        La fiesta del chivo 5        |       Juan Rulfo       |      Editorial Losada      | 1949 |
# | 1000000044 |       La ciudad y los perros 8      |     Roberto Bolaño     |       Editorial Sur        | 1901 |
# | 1000000045 |  Crónica de una muerte anunciada 5  |  Miguel de Cervantes   |        Oveja Negra         | 1905 |
# | 1000000046 |      Don Quijote de la Mancha 5     |     Julio Cortázar     |      Editorial Losada      | 1974 |
# | 1000000047 |     La región más transparente 5    | Gabriel García Márquez | Fondo de Cultura Económica | 1914 |
# | 1000000048 |        Cien años de soledad 4       |     Ernesto Sabato     |        Oveja Negra         | 1933 |
# | 1000000049 |      Como agua para chocolate 9     |     Roberto Bolaño     |     Editorial Anagrama     | 1975 |
# | 1000000050 |            Pedro Páramo 4           |     Roberto Bolaño     |          Planeta           | 1936 |
# | 1000000051 |        La fiesta del chivo 1        |     Carlos Fuentes     |     Editorial Anagrama     | 1999 |
# | 1000000052 |        Cien años de soledad 4       |  Miguel de Cervantes   |        Oveja Negra         | 2013 |
# | 1000000053 |        La fiesta del chivo 5        |     Ernesto Sabato     |        Oveja Negra         | 1975 |
# | 1000000054 |      Don Quijote de la Mancha 8     |     Carlos Fuentes     |            Sur             | 1906 |
# | 1000000055 |       La ciudad y los perros 2      |       Juan Rulfo       |    Francisco de Robles     | 1903 |
# | 1000000056 |        La fiesta del chivo 4        |  Miguel de Cervantes   |        Oveja Negra         | 1985 |
# | 1000000057 |      Don Quijote de la Mancha 2     |     Roberto Bolaño     |          Planeta           | 1925 |
# | 1000000058 |            Santa Evita 9            |   Carlos Ruiz Zafón    |   Editorial Sudamericana   | 1970 |
# | 1000000059 |        La fiesta del chivo 6        |   Carlos Ruiz Zafón    |   Editorial Sudamericana   | 1905 |
# | 1000000060 |  Crónica de una muerte anunciada 2  |     Roberto Bolaño     |          Planeta           | 1920 |
# | 1000000061 |              Rayuela 6              |     Carlos Fuentes     |     Editorial Anagrama     | 1974 |
# | 1000000062 |                Aura 3               | Gabriel García Márquez |        Oveja Negra         | 1992 |
# | 1000000063 |            Pedro Páramo 1           |       Juan Rulfo       | Fondo de Cultura Económica | 1985 |
# | 1000000064 |      Don Quijote de la Mancha 4     |     Julio Cortázar     |        Oveja Negra         | 1990 |
# | 1000000065 |      Don Quijote de la Mancha 6     |     Carlos Fuentes     |      Editorial Losada      | 1944 |
# | 1000000066 |      Los detectives salvajes 2      |   Jorge Luis Borges    |          Planeta           | 1908 |
# | 1000000067 |      La casa de los espíritus 8     |     Roberto Bolaño     |     Editorial Anagrama     | 1928 |
# | 1000000068 |      Los detectives salvajes 5      |       Juan Rulfo       |   Editorial Sudamericana   | 1901 |
# | 1000000069 |        Noticias del imperio 7       |     Julio Cortázar     |        Oveja Negra         | 1941 |
# | 1000000070 |      Como agua para chocolate 3     |     Ernesto Sabato     |    Francisco de Robles     | 2015 |
# | 1000000071 |            Pedro Páramo 3           |     Ernesto Sabato     | Fondo de Cultura Económica | 1973 |
# | 1000000072 |        Cien años de soledad 7       |   Jorge Luis Borges    |       Editorial Sur        | 1971 |
# | 1000000073 |  Crónica de una muerte anunciada 4  |  Miguel de Cervantes   |       Editorial Sur        | 1992 |
# | 1000000074 |        La fiesta del chivo 1        |       Juan Rulfo       |   Editorial Sudamericana   | 1960 |
# | 1000000075 |  Crónica de una muerte anunciada 8  |     Ernesto Sabato     |       Editorial Sur        | 1902 |
# | 1000000076 |             Ficciones 9             |       Juan Rulfo       |   Editorial Sudamericana   | 1963 |
# | 1000000077 |      La casa de los espíritus 4     |   Carlos Ruiz Zafón    |       Editorial Sur        | 1938 |
# | 1000000078 |       La ciudad y los perros 1      |   Carlos Ruiz Zafón    |     Editorial Anagrama     | 1997 |
# | 1000000079 |  Crónica de una muerte anunciada 3  | Gabriel García Márquez |       Editorial Sur        | 1977 |
# | 1000000080 |      Los detectives salvajes 1      |     Roberto Bolaño     |    Francisco de Robles     | 1913 |
# | 1000000081 |        La sombra del viento 9       |     Carlos Fuentes     |    Francisco de Robles     | 1977 |
# | 1000000082 |       La ciudad y los perros 2      |     Carlos Fuentes     |      Editorial Losada      | 2023 |
# | 1000000083 |        Cien años de soledad 2       |       Juan Rulfo       |            Sur             | 1922 |
# | 1000000084 |       Sobre héroes y tumbas 10      |   Carlos Ruiz Zafón    |     Editorial Anagrama     | 1996 |
# | 1000000085 |            Pedro Páramo 4           |  Miguel de Cervantes   | Fondo de Cultura Económica | 1954 |
# | 1000000086 |        Cien años de soledad 5       | Gabriel García Márquez |     Editorial Anagrama     | 1920 |
# | 1000000087 |            Santa Evita 4            |     Ernesto Sabato     |            Sur             | 1973 |
# | 1000000088 |      Los detectives salvajes 7      | Gabriel García Márquez |            Sur             | 1970 |
# | 1000000089 |              El Aleph 3             |     Carlos Fuentes     |     Editorial Anagrama     | 1904 |
# | 1000000090 |        La fiesta del chivo 9        |     Roberto Bolaño     |            Sur             | 1974 |
# | 1000000091 | El amor en los tiempos del cólera 7 |     Roberto Bolaño     |   Editorial Sudamericana   | 1958 |
# | 1000000092 |      La casa de los espíritus 5     |   Carlos Ruiz Zafón    |      Editorial Losada      | 1939 |
# | 1000000093 |              El túnel 9             |  Miguel de Cervantes   |        Oveja Negra         | 1978 |
# | 1000000094 |              El Aleph 9             |     Roberto Bolaño     |    Francisco de Robles     | 2012 |
# | 1000000095 |       Sobre héroes y tumbas 6       | Gabriel García Márquez |     Editorial Anagrama     | 1931 |
# | 1000000096 |        La sombra del viento 4       |   Jorge Luis Borges    |    Francisco de Robles     | 1909 |
# | 1000000097 |  Crónica de una muerte anunciada 6  |   Carlos Ruiz Zafón    | Fondo de Cultura Económica | 1920 |
# | 1000000098 |      Don Quijote de la Mancha 1     | Gabriel García Márquez | Fondo de Cultura Económica | 1929 |
# | 1000000099 |      Como agua para chocolate 7     |     Ernesto Sabato     |        Oveja Negra         | 1934 |
# | 1000000100 |              Rayuela 8              | Gabriel García Márquez |          Planeta           | 1933 |
# | 1000000101 |               Prueba 2              |        Andres s        |     Editorial Anagrama     | 1994 |
# | 1100000001 |                Prueba               |        Andres s        |     Editorial Anagrama     | 2001 |
# +------------+-------------------------------------+------------------------+----------------------------+------+
#
#
# ---Menú de Biblioteca---
# 1. Agregar Usuario
# 2. Agregar Libro
# 3. Mostrar Libros
# 4. Buscar Libro
# 5. Recuperar ultimo libro consultado
# 6. Prestar Libro
# 7. Mostrar libros prestados
# 8. Devolver Libro
# ------------------------
# 9.  Buscar Usuario
# 10. Mostrar Usuarios
# 11. Buscar Libro
# 12. Buscar Libros por editorial y autor
# 13. Mostrar Libros
# ------------------------
# 0. Salir
# ------------------------
# Selecciona una opción: 12
# Ingrese el nombre de la editorial: Editorial Anagrama
# Ingrese el nombre del autor: Andres s
# +------------+----------+----------+--------------------+------+
# |    isbn    |  Titulo  |  Autor   |     Editorial      | Año  |
# +------------+----------+----------+--------------------+------+
# | 1100000001 |  Prueba  | Andres s | Editorial Anagrama | 2001 |
# | 1000000101 | Prueba 2 | Andres s | Editorial Anagrama | 1994 |
# +------------+----------+----------+--------------------+------+
#
#
# ---Menú de Biblioteca---
# 1. Agregar Usuario
# 2. Agregar Libro
# 3. Mostrar Libros
# 4. Buscar Libro
# 5. Recuperar ultimo libro consultado
# 6. Prestar Libro
# 7. Mostrar libros prestados
# 8. Devolver Libro
# ------------------------
# 9.  Buscar Usuario
# 10. Mostrar Usuarios
# 11. Buscar Libro
# 12. Buscar Libros por editorial y autor
# 13. Mostrar Libros
# ------------------------
# 0. Salir
# ------------------------
# Selecciona una opción: 0
# Saliendo del sistema...

# %% [markdown]
# # Clase Biblioteca
# En la biblioteca se encuentra centralizada las funcionalidades de los libros y los usuarios.
# Tambien en esta clase se almacenará la informacion de libros y usuarios.

# %%
import sys
import pandas as pd

class Library:
    def __init__(self):
        self.books       = [] # Lista de libros
        self.users       = [] # Lista de usuarios
        self.bookHistory = [] # Pila - Historial de libros buscados
        self.librarians = Librarian('9000001', 'Bibliotecario 1')
        self.bookBinaryTree = BookBinaryTree()
        self.userBinaryTree = UserBinaryTree()
        self.bookNTree      = BookNTree()

#--- Agregar un usuario a la biblioteca
    def addUser(self):
        self.librarians.addUser(self)

#--- Agregar un libro a la biblioteca
    def addBook(self):
        self.librarians.addBook(self)

#--- Prestar un libro
    def lendBook(self):
        self.librarians.lendBook(self)

#--- Devolver un libro
    def returnBook(self):
        self.librarians.returnBook(self)

#--- Buscar Libro
    def searchBook(self):
        User.searchBook(self)

#--- Recuperar ultimo libro consultado
    def recoverHistoryBook(self):
        if not self.bookHistory:
            print("No hay libros en el historial.")
            return

        book = self.bookHistory.pop() # Retirar libro del tope de la pila
        print(book.__str__())

#--- Mostar libros prestados
    def showLentBooks(self):
        for user in self.users:
            print(f"Usuario: {user.name}")
            if not user.books:
                print(f"    Libro: N/A")

            for book in user.books:
                print(f"    Libro: {book.title}")

#--- Mostrar información de los libros
    def showBooks(self):
        for book in self.books:
            print(book.__str__())

#--- Mostrar información de los usuarios
    def showUsers(self):
        for user in self.users:
            print(user)

#--- Salir del sistema
    def exit(self):
        print("Saliendo del sistema...")

#--- Funcionalidad nueva (Estructuras de datos no lineales) ---#

#--- Buscar Libro por isbn
    def searchBookTree(self):
        isbn = input("Ingrese el ISBN del libro: ")
        self.bookBinaryTree.search(isbn)

#--- Mostrar libros
    def showBooksTree(self):
        self.bookBinaryTree.showBooks();

#--- Buscar Usuario por id
    def searchUserTree(self):
        id = input("Ingrese el id del usuario: ")
        self.userBinaryTree.search(id)

#--- Mostrar usuarios
    def showUsersTree(self):
        self.userBinaryTree.showUsers()

#--- Obtener libro por editorial y autor
    def searchBookNTree(self):
        editorial = input("Ingrese el nombre de la editorial: ")
        autor     = input("Ingrese el nombre del autor: ")
        self.bookNTree.search(editorial, autor)

#--- Cargar Informacion
    def loadData(self):
        # Libros
        dfu = pd.read_json('https://raw.githubusercontent.com/P-1-P-3/SGB/refs/heads/main/libros_mixtos.json')
        for index, row in dfu.iterrows():
            book = Book(row['isbn'], row['title'], row['author'], row['editorial'], row['year'])
            self.books.append(book)
            self.bookBinaryTree.insert(book)
            self.bookNTree.insert(book)

        # Usuarios
        dfb = pd.read_json('https://raw.githubusercontent.com/P-1-P-3/SGB/refs/heads/main/usuarios.json')
        for index, row in dfb.iterrows():
            user = User(row['idUsers'], row['name'], row['email'])
            self.users.append(user)
            self.userBinaryTree.insert(user)

# %% [markdown]
# # Clase Usuario
# Esta clase se usara para crear el usuario, tambien tendra las funcinalidades que puede ejecutar el usuario.

# %%
class User:
    def __init__(self, idUsers, nombre, email):
        self.idUsers = idUsers # Identificador único de un usuario
        self.name    = nombre  # Nombre del usuario
        self.email   = email   # Correo del usuario
        self.books   = []      # Lista de libros que el usuario tiene en prestamo

#--- Prestar un libro
    def lendABook(self, book):
        if book.available:
            book.changeAvailability(False)  # Cambiar disponibilidad del libro
            self.books.append(book)         # Agregar libro a la lista de libros prestados al usuario
            print(f"El libro {book.title} ha sido prestado a {self.name}")
        else:
            # Si el libro no esta disponible agregamos al usuario a la Cola - lista de espera para prestamo
            book.enqueueUser(self)
            print(f"El libro {book.title} no está disponible.")
            print(f"{self.name} ha sido agregado a la lista de espera.")

#--- Devolver un libro
    def returnABook(self, book):
        if book in self.books:              # Verificar si el libro ha sido prestado al usuario
            book.changeAvailability(True)   # Cambiar disponibilidad del libro
            self.books.remove(book)         # Eliminar libro de la lista de libros prestados al usuario
            print(f"El libro {book.title} ha sido devuelto")
            book.dequeueUser()              # Al devolver se asigna el libro al primer usuario de la cola
        else:
            print(f"El libro {book.title} no ha sido prestado a {self.name}")

#--- Buscar Libro
    @staticmethod
    def searchBook(library):
        isbn = input("Ingrese el ISBN del libro: ")
        # Buscar libro por ISBN
        book = next((book for book in library.books if book.isbn == isbn), None);

        # Mostrar resultado de busqueda
        if book:
            library.bookHistory.append(book) # Agregar libro encontrado en el tope de la pila
            print(f'Libro encontrado: {book.__str__()}')
        else:
            print('No se encontro ningun libro')

# %% [markdown]
# # Clase Libro
# Esta clase se usa para crear un libro, tambien tendra la funcionalidad que se podra ejecutar en cada instancia del libro.

# %%
class Book:
    def __init__(self, isbn, title, author, editorial, year):
        self.isbn      = isbn      #  Identificador único de un libro
        self.title     = title     #  Título del libro
        self.author    = author    #  Autor del libro
        self.editorial = editorial #  Editorial del libro
        self.year      = year      #  Año de publicación del libro
        self.available = True      #  Disponibilidad del libro
        self.users     = []        #  Cola - Usuarios que esperan para un libro prestado

#--- Mostrar información del libro
    def __str__(self):
        return f"{self.isbn} - {self.title} - {self.author} - {self.editorial} - {self.year} - {'Disponible' if self.available else 'No disponible'}"

#--- Cambiar disponibilidad del libro
    def changeAvailability(self, available):
        self.available = available
        print(f"El libro {self.title} ahora está {'disponible' if self.available else 'no disponible'}")

#--- Encolar Usuario en lista de espera para un libro prestado
    def enqueueUser(self, user: User):
        self.users.append(user)

#--- Desencolar Usuario
    def dequeueUser(self):
        # Verificar si el libro tiene usuarios que quieran solicitar el prestamo
        if self.users:
            user: User = self.users.pop(0)
            user.lendABook(self) # Se presta el libro al usuario

# %% [markdown]
# # Clase Bibliotecario
#
# Esta clase se usa para crear un bibliotecario.

# %%
class Librarian:
    def __init__(self, idLibrarian, name):
        self.idLibrarian = idLibrarian # Identificador único del bibliotecario
        self.name        = name        # Nombre del bibliotecario

#--- Agregar un libro a la biblioteca
    def addBook(self, library):
        isbn      = input("Ingresa el ISBN del libro: ")
        title     = input("Ingresa el título del libro: ")
        author    = input("Ingresa el autor del libro: ")
        editorial = input("Ingresa la editorial del libro: ")
        year      = input("Ingresa el año de publicación del libro: ")

        book = Book(isbn, title, author, editorial, year)    # Crear un objeto de tipo Book
        library.books.append(book)                           # Agregar el libro a la lista de libros
        library.bookBinaryTree.insert(book)                  # Agregar el libro a estructura tipo arbol
        library.bookNTree.insert(book)                       # Agregar el libro a estructura tipo arbol
        print(f"El libro {book.title} ha sido agregado")

#--- Prestar un libro
    def lendBook(self, library):
        idUser = input("Ingresa el id del usuario: ")
        idBook = input("Ingresa el ISBN del libro: ")

        # Buscar usuario y libro
        user: User = next((user for user in library.users if user.idUsers == idUser), None)
        book: Book = next((book for book in library.books if book.isbn == idBook), None)

        # Verificar si el usuario y el libro existen y si el libro está disponible
        if user and book:
            user.lendABook(book)  # Prestar el libro al usuario. Cambiar disponibilidad del libro
        else:
            print("Usuario o libro no encontrado")

#--- Devolver un libro
    def returnBook(self, library):
        idUser = input("Ingresa el id del usuario: ")
        idBook = input("Ingresa el ISBN del libro: ")

        # Buscar usuario y libro
        user: User = next((user for user in library.users if user.idUsers == idUser), None)
        book: Book = next((book for book in library.books if book.isbn == idBook), None)

        # Verificar si el usuario y el libro existen y si el libro ha sido prestado al usuario
        if user and book:
            user.returnABook(book)
        else:
            print("Usuario o libro no encontrado")

#--- Agregar un usuario a la biblioteca
    def addUser(self, library):
        inId    = input("Ingresa el id del usuario: ")
        inName  = input("Ingresa el nombre del usuario: ")
        inEmail = input("Ingresa el correo del usuario: ")

        user = User(inId, inName, inEmail) # Crear un objeto de tipo User

        library.users.append(user)          # Agregar el usuario a la lista de usuarios
        library.userBinaryTree.insert(user) # Agregar el libro a estructura tipo arbol
        print(f"El usuario {user.name} ha sido agregado")

# %% [markdown]
# # Arbol Binario Usuario

# %%
from prettytable import PrettyTable

class NodeUser:
    def __init__(self, user: User):
        self.user  = user
        self.left  = None
        self.right = None

class UserBinaryTree:
    def __init__(self):
        self.root = None
        self.field_names = ["ID", "Nombre", "Correo"]

#--- Insertar Usuario
    def insert(self, user: User):
        if self.root is None:
            self.root = NodeUser(user)
        else:
            user.idUsers = int(user.idUsers)
            self._insert(user, self.root)

    def _insert(self, user: User, node: NodeUser):
        if user.idUsers < node.user.idUsers:
            if node.left is None:
                node.left = NodeUser(user)
            else:
                self._insert(user, node.left)
        else:
            if node.right is None:
                node.right = NodeUser(user)
            else:
                self._insert(user, node.right)

#--- Mostrar Usuarios
    def showUsers(self):
      table = PrettyTable()
      table.field_names = self.field_names
      dataUsers = self._inorden(self.root, table)
      print(table)

    def _inorden(self, node: NodeUser, table: PrettyTable):
      if node:
        self._inorden(node.left, table)
        table.add_row([node.user.idUsers, node.user.name, node.user.email])
        self._inorden(node.right, table)

#--- Buscar Usuario
    def search(self, idUser):
        if self.root is None:
            return None
        else:
            table = PrettyTable()
            table.field_names = self.field_names

            user = self._search(idUser, self.root)
            table.add_row([user.idUsers, user.name, user.email])
            print(table)

    def _search(self, idUser, node: NodeUser):
        if node.user.idUsers == int(idUser):
            return node.user
        elif int(idUser) > node.user.idUsers:
            return self._search(idUser, node.right)
        else:
            return self._search(idUser, node.left)

# %% [markdown]
# # Arbol Binario Libro

# %%
from prettytable import PrettyTable

class Node:
    def __init__(self, book: Book):
        self.book  = book
        self.left  = None
        self.right = None

class BookBinaryTree:
    def __init__(self):
        self.root = None
        self.field_names = ["isbn", "Titulo", "Autor", "Editorial", "Año",]

#--- Insertar libro
    def insert(self, book: Book):
        if self.root is None:
            self.root = Node(book)
        else:
            book.isbn = int(book.isbn)
            self._insert(book, self.root)

    def _insert(self, book: Book, node: Node):
        if book.isbn < node.book.isbn:
            if node.left is None:
                node.left = Node(book)
            else:
                self._insert(book, node.left)
        else:
            if node.right is None:
                node.right = Node(book)
            else:
                self._insert(book, node.right)

#--- Mostrar Libros
    def showBooks(self):
      table = PrettyTable()
      table.field_names = self.field_names
      self._inorden(self.root, table)
      print(table)

    def _inorden(self, node: Node, table: PrettyTable):
      if node:
        self._inorden(node.left, table)
        table.add_row([
            node.book.isbn,
            node.book.title,
            node.book.author,
            node.book.editorial,
            node.book.year,
        ])
        self._inorden(node.right, table)

#--- Buscar libro por isbn
    def search(self, isbn):
        if self.root is None:
            return None
        else:
          table = PrettyTable()
          table.field_names = self.field_names

          book = self._search(isbn, self.root)
          table.add_row([
            book.isbn,
            book.title,
            book.author,
            book.editorial,
            book.year,
          ])
          print(table)


    def _search(self, isbn, node: Node):
        if node.book.isbn == int(isbn):
            return node.book
        elif int(isbn) > node.book.isbn:
            return self._search(isbn, node.right)
        else:
            return self._search(isbn, node.left)

# %% [markdown]
# # Arbol n-ario Libro

# %%
from prettytable import PrettyTable

class NodeBook:
    def __init__(self, value, type):
        self.value     = value # valor del nodo (Editorial, Autor, Libro)
        self.type     = type   # tipo del nodo (editorial, autor, libro)
        self.children = []     # Lista de nodos hijos

class BookNTree:
    def __init__(self):
        self.root        = None
        self.field_names = ["isbn", "Titulo", "Autor", "Editorial", "Año"]

#--- Insertar Editorial, Autor, Libro
    def insert(self, book: Book):
        editorial = book.editorial
        author    = book.author

        if self.root is None:
            self.root = NodeBook(editorial, "editorial")

        currentNode = self.root

        # Buscar editorial
        editorialNode = self._findChildNode(currentNode, editorial, "editorial")
        if editorialNode is None: # Crea el editorial si no se encuentra.
            editorialNode = NodeBook(editorial, "editorial")
            currentNode.children.append(editorialNode)

        currentNode = editorialNode

        # Buscar autor
        authorNode = self._findChildNode(currentNode, author, "autor")
        if authorNode is None: # Crea el autor si no se encuentra.
            authorNode = NodeBook(author, "autor")
            currentNode.children.append(authorNode)

        currentNode = authorNode

        # Insertar libro
        bookNode = self._findChildNode(currentNode, book, "libro")
        if bookNode is None:
            currentNode.children.append(NodeBook(book, "libro"))

#--- Encuentra el nodo hijo
    def _findChildNode(self, node: NodeBook, value, type):
        for child in node.children:
            if child.value == value and child.type == type:
                return child
        return None

#--- Buscar libro por editorial y autor
    def search(self, editorial, autor):
        if self.root is None:
            print("No hay libros en la biblioteca")
            return

        # Buscar editorial
        editorialNode = self._findChildNode(self.root, editorial, "editorial")
        if editorialNode is None:
            print("Editorial no encontrada")
            return

        # Buscar autor
        autorNode = self._findChildNode(editorialNode, autor, "autor")
        if autorNode is None:
            print("Autor no encontrado")
            return

        # Buscar libro
        table = PrettyTable()
        table.field_names = self.field_names

        for child in autorNode.children:
            if child.type == "libro":
                table.add_row([
                  child.value.isbn,
                  child.value.title,
                  child.value.author,
                  child.value.editorial,
                  child.value.year,
                ])
        print(table)
